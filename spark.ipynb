# %%
from pyspark import SparkContext

# %%
sc = SparkContext(appName='MySparkApp')

# %%
sc.stop()

# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName(name='test1')

# %%
spark.getOrCreate()
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://DESKTOP-BS0HC10:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>create-df</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
df = spark.getOrCreate()

# %%
dff = df.read.csv('dengue.csv',header=True)

# %%
dff.printSchema()
# Out:
# root
#  |-- serial: string (nullable = true)
#  |-- tempmax: string (nullable = true)
#  |-- tempmin: string (nullable = true)
#  |-- temp: string (nullable = true)
#  |-- feelslikemax: string (nullable = true)
#  |-- feelslikemin: string (nullable = true)
#  |-- feelslike: string (nullable = true)
#  |-- dew: string (nullable = true)
#  |-- humidity: string (nullable = true)
#  |-- precip: string (nullable = true)
#  |-- precipprob: string (nullable = true)
#  |-- precipcover: string (nullable = true)
#  |-- snow: string (nullable = true)
#  |-- snowdepth: string (nullable = true)
#  |-- windspeed: string (nullable = true)
#  |-- winddir: string (nullable = true)
#  |-- sealevelpressure: string (nullable = true)
#  |-- cloudcover: string (nullable = true)
#  |-- visibility: string (nullable = true)
#  |-- solarradiation: string (nullable = true)
#  |-- solarenergy: string (nullable = true)
#  |-- uvindex: string (nullable = true)
#  |-- conditions: string (nullable = true)
# ...

# %%
dff.show()
# Out:
# +------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+-----------------+------------------+------------------+------------------+----+---------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+-----------------+------------------+------------------+-------+------+
# |serial|           tempmax|           tempmin|              temp|      feelslikemax|      feelslikemin|         feelslike|               dew|         humidity|            precip|        precipprob|       precipcover|snow|snowdepth|         windspeed|           winddir|  sealevelpressure|        cloudcover|        visibility|    solarradiation|       solarenergy|          uvindex|        conditions|          stations|  cases|labels|
# ...

# %%
from pyspark.sql.types import StructType, StructField

# %%
spark.stop()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 spark.stop()
#
# AttributeError: 'Builder' object has no attribute 'stop'
